# %%
# %load_ext autoreload
# %autoreload 2

from loadprofileanalyzer import LoadProfileAnalyzer, Config
# Out:
# /home/chriko/.local/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %%
config = Config("./config.yml")
# Out:
# INFO:config:Reading consumption timeseries
# INFO:config:Consumption timeseries loaded.
# INFO:config:Assuming year.
# INFO:config:Assumed year to be 2023.
# INFO:config:Creating price timeseries from fixed price.
# INFO:config:Price timeseries successfully created.
# WARNING:config:We can't integrate negative prices yet. We set the negative prices in your price timeseries to 0.
# INFO:config:Checking length of timeseries.
# INFO:config:Timeseries length check passed.
# INFO:config:Config class initialized successfully.

# %%
lpa = LoadProfileAnalyzer(config=config)
# Out:
# INFO:root:Built default ESM
# INFO:root:Added storage
# INFO:root:Creating pyomo model.
# INFO:root:Optimizing. Depending on the given parameters and your setup, this may take a while.
# Set parameter OutputFlag to value 1
# INFO:gurobipy:Set parameter OutputFlag to value 1
# Set parameter Threads to value 3
# INFO:gurobipy:Set parameter Threads to value 3
# Set parameter LogFile to value ""
# INFO:gurobipy:Set parameter LogFile to value ""
# Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter LogToConsole to value 0
# INFO:gurobipy:Set parameter QCPDual to value 1
# INFO:gurobipy:Gurobi Optimizer version 12.0.1 build v12.0.1rc0 (linux64 - "Ubuntu 24.04.2 LTS")
# INFO:gurobipy:
# INFO:gurobipy:CPU model: Intel(R) Core(TM) Ultra 7 155H, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy:Thread count: 22 physical cores, 22 logical processors, using up to 3 threads
# INFO:gurobipy:
# INFO:gurobipy:Non-default parameters:
# INFO:gurobipy:LogToConsole  0
# ...

# %%
src_opt = lpa.esm.componentModelingDict["SourceSinkModel"].getOptimalValues("operationVariablesOptimum")["values"]
src_opt.loc[("grid", "grid")].max()
# Out:
# 1979.4689763779547

# %%
lpa.esm.getOptimizationSummary("TransmissionModel")
# Out:
#                                                                           consumption_site  \
# Component      Property                        Unit      LocationIn
# capacity_price NPVcontribution                 [Euro]    consumption_site                0
#                                                          grid                412745.410565
#                TAC                             [Euro/a]  consumption_site                0
#                                                          grid                412745.410565
#                capacity                        [kWh]     consumption_site              NaN
#                                                          grid                  7917.875906
#                capexCap                        [Euro/a]  consumption_site              NaN
#                                                          grid                412745.410565
# ...
